# %% [markdown]
# # YOLOv8-Sign Language detection

# %%
#from ultralytics import YOLO
 
 Load the model.
 model = YOLO('yolov8n.pt')
 
 Training.
 results = model.train(
    data='data_path\data.yaml',    
    imgsz=640,
    epochs=50,
    batch=8,
 )

# %% [markdown]
# ## Loading Sign Language pre-trained model

# %%
from ultralytics import YOLO
model = YOLO('weight_path'\sign-language.pt')

# %% [markdown]
# ## Prediction(1)

# %%
from PIL import Image
# from PIL
im1 = Image.open('input image_path')
results = model.predict(source=im1, save=True)
# Out:
# 0: 640x640 1 how are you-, 142.6ms
# Speed: 4.0ms preprocess, 142.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict9

# %% [markdown]
# ## Detection

# %%
display(Image.open('runs/detect/predict9/sg6.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %% [markdown]
# ## Prediction(2)

# %%
from PIL import Image
# from PIL
im1 = Image.open('input image_path')
results = model.predict(source=im1, save=True)  # save plotted images
# Out:
# 0: 640x640 1 understand, 135.6ms
# Speed: 3.0ms preprocess, 135.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict9

# %% [markdown]
# ## Detection

# %%
display(Image.open('runs/detect/predict9/sg8.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %% [markdown]
# ## Prediction(3)

# %%
from PIL import Image
# from PIL
im1 = Image.open('input image_path')
results = model.predict(source=im1, save=True)  # save plotted images
# Out:
# 0: 640x640 1 good-bsl-, 1 please, 145.6ms
# Speed: 3.0ms preprocess, 145.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict9

# %% [markdown]
# ## Detection

# %%
display(Image.open('runs/detect/predict9/sg5.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %% [markdown]
# ## Prediction(4)

# %%
from PIL import Image
# from PIL
im1 = Image.open('input image_path')
results = model.predict(source=im1, save=True)  # save plotted images
# Out:
# 0: 640x640 1 U, 1 bye, 129.7ms
# Speed: 6.0ms preprocess, 129.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict9

# %% [markdown]
# ## Detection

# %%
#print(results)
display(Image.open('runs/detect/predict9/sg3.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>
